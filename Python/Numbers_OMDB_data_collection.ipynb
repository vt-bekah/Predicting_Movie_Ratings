# %% [markdown]
# # **NOTE: that running this notebook will take TENS of minutes due to the OMDB API calls!**

# %% [markdown]
# # Import Dependencies

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from scipy.stats import linregress
import pandas as pd
import numpy as np
import requests

browser = Browser('chrome')

# %% [markdown]
# # Iterating through Numbers pages to store all the data

# %%
numbers_url = "https://www.the-numbers.com/movie/budgets/all"
browser.visit(numbers_url)

# Create empty lists for rows
headers = []
data_rows = []

# Create the full list of page clicks
all_page_clicks=[]
all_page_numbers = np.arange(101, 6501, 100)
for page in all_page_numbers:
    if page < 1000:
        all_page_clicks.append(str(page)+"-")
    elif page < 10000:
        if page%1000 == 1:
            all_page_clicks.append(str(page//1000)+",001-")
        else:
            all_page_clicks.append(str(page//1000)+","+str(page%1000))

for i in range(len(all_page_numbers)+1):
    # Scrape the website
    html = browser.html
    # Create a Beautiful Soup object
    soup = BeautifulSoup(html, "html.parser")
    # Extract all rows
    all_rows = soup.find_all("tr")
    
    # Loop through the scraped data to create a list of headers for first iteration only
    if i == 0:
        header_scrape = all_rows[0].find_all("th")
        for header in header_scrape:
            headers.append(header.text)

    # Loop through the scraped data to create a list of data rows
    for row in all_rows[1:]:
        data = []
        for r in row.find_all("td"):
            data.append(r.text)
        data_rows.append(data)
    if i < len(all_page_numbers):
        if i%5 == 0:
            print("clicking " + all_page_clicks[i])
        browser.links.find_by_partial_text(all_page_clicks[i]).click()
# Out:
# clicking 101-
# clicking 601-
# clicking 1,101
# clicking 1,601
# clicking 2,101
# clicking 2,601
# clicking 3,101
# clicking 3,601
# clicking 4,101
# clicking 4,601
# clicking 5,101
# clicking 5,601
# clicking 6,101

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
movies_df = pd.DataFrame(data_rows, columns=headers)
movies_df
# Out:
#               ReleaseDate                                        Movie  \
# 0         1   Dec 9, 2022                     Avatar: The Way of Water
# 1         2  Apr 23, 2019                            Avengers: Endgame
# 2         3  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3         4  Apr 22, 2015                      Avengers: Age of Ultron
# 4         5  May 17, 2023                                       Fast X
# ...     ...           ...                                          ...
# 6439  6,440   Apr 2, 1999                                    Following
# 6440  6,441  Jul 13, 2005                Return to the Land of Wonders
# 6441  6,442  Sep 29, 2015                         A Plague So Pleasant
# 6442  6,443   Aug 5, 2005                            My Date With Drew
# 6443  6,444   Mar 2, 2021                                       Neeras
#
#      ProductionBudget  DomesticGross   WorldwideGross
# 0        $460,000,000   $684,075,767   $2,319,591,720
# 1        $400,000,000   $858,373,000   $2,788,912,285
# 2        $379,000,000   $241,071,802   $1,045,713,802
# 3        $365,000,000   $459,005,868   $1,395,316,979
# 4        $340,000,000   $145,960,660     $714,414,576
# ...               ...            ...              ...
# 6439           $6,000        $48,482         $240,495
# 6440           $5,000         $1,338           $1,338
# 6441           $1,400             $0               $0
# 6442           $1,100       $181,041         $181,041
# 6443              $86             $0               $0
#
# [6444 rows x 6 columns]

# %%
# Drop the website's index column
movies_df = movies_df[['ReleaseDate', 'Movie', 'ProductionBudget', 'DomesticGross', 'WorldwideGross']]
movies_df.head()
# Out:
#     ReleaseDate                                        Movie ProductionBudget  \
# 0   Dec 9, 2022                     Avatar: The Way of Water     $460,000,000
# 1  Apr 23, 2019                            Avengers: Endgame     $400,000,000
# 2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides     $379,000,000
# 3  Apr 22, 2015                      Avengers: Age of Ultron     $365,000,000
# 4  May 17, 2023                                       Fast X     $340,000,000
#
#    DomesticGross   WorldwideGross
# 0   $684,075,767   $2,319,591,720
# 1   $858,373,000   $2,788,912,285
# 2   $241,071,802   $1,045,713,802
# 3   $459,005,868   $1,395,316,979
# 4   $145,960,660     $714,414,576

# %% [markdown]
# # Pull the OMDBAPI Data
#
# **NOTE THIS QUERY TAKES A WHILE TO COMPLETE**
#
# Leverages the movie list from the Numbers scrape

# %%
# Chris' OMDB API key (250k a day = 1 data pull a day)
# api_key = 'ac6cb27f'
# Bekah's OMDB API key (250k a day = 1 data pull a day)
api_key = '2ec19c8d'

# Base URL for OMDB API
omdb_url = 'http://www.omdbapi.com/'

# Do query with type = movie restriction to try and avoid mapping to series with the same name
def get_movie_details(title):
    params = {'apikey': api_key, 't': title, 'type':'movie'}
    response = requests.get(omdb_url, params=params)
    data = response.json()
    return data

# Define a list of fields you want to extract from the API response
fields_to_extract = ['Title', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 
                     'Writer', 'Actors', 'Language', 'Country', 'Type', 'Metascore', 
                     'imdbRating', 'imdbVotes', 'BoxOffice', 'Production']

# %%
# Iterate through each row in the DataFrame and append selected fields from the API response
for index, row in movies_df.iterrows():
    movie_title = row['Movie']
    movie_details = get_movie_details(movie_title)

    # Append selected fields to the DataFrame
    for field in fields_to_extract:
        column_name = f'OMDB_{field}'
        movies_df.at[index, column_name] = movie_details.get(field, '')

movies_df
# Out:
#        ReleaseDate                                        Movie  \
# 0      Dec 9, 2022                     Avatar: The Way of Water
# 1     Apr 23, 2019                            Avengers: Endgame
# 2     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3     Apr 22, 2015                      Avengers: Age of Ultron
# 4     May 17, 2023                                       Fast X
# ...            ...                                          ...
# 6439   Apr 2, 1999                                    Following
# 6440  Jul 13, 2005                Return to the Land of Wonders
# 6441  Sep 29, 2015                         A Plague So Pleasant
# 6442   Aug 5, 2005                            My Date With Drew
# 6443   Mar 2, 2021                                       Neeras
#
#      ProductionBudget  DomesticGross   WorldwideGross  \
# 0        $460,000,000   $684,075,767   $2,319,591,720
# 1        $400,000,000   $858,373,000   $2,788,912,285
# 2        $379,000,000   $241,071,802   $1,045,713,802
# 3        $365,000,000   $459,005,868   $1,395,316,979
# 4        $340,000,000   $145,960,660     $714,414,576
# ...               ...            ...              ...
# 6439           $6,000        $48,482         $240,495
# 6440           $5,000         $1,338           $1,338
# 6441           $1,400             $0               $0
# 6442           $1,100       $181,041         $181,041
# 6443              $86             $0               $0
#
#                                        OMDB_Title OMDB_Rated OMDB_Released  \
# 0                        Avatar: The Way of Water      PG-13   16 Dec 2022
# 1                               Avengers: Endgame      PG-13   26 Apr 2019
# 2     Pirates of the Caribbean: On Stranger Tides      PG-13   20 May 2011
# 3                         Avengers: Age of Ultron      PG-13   01 May 2015
# 4                                          Fast X      PG-13   19 May 2023
# ...                                           ...        ...           ...
# 6439                                    Following          R   05 Nov 1999
# 6440                Return to the Land of Wonders        N/A   27 Apr 2004
# 6441                         A Plague So Pleasant        N/A   26 Jan 2013
# 6442                            My Date with Drew         PG   30 Sep 2005
# 6443                                       Neeras  Not Rated   02 Mar 2021
#
#      OMDB_Runtime                  OMDB_Genre  ...  \
# 0         192 min  Action, Adventure, Fantasy  ...
# 1         181 min    Action, Adventure, Drama  ...
# 2         136 min  Action, Adventure, Fantasy  ...
# 3         141 min   Action, Adventure, Sci-Fi  ...
# 4         141 min    Action, Adventure, Crime  ...
# ...           ...                         ...  ...
# 6439       69 min    Crime, Mystery, Thriller  ...
# 6440       88 min            Documentary, War  ...
# 6441       76 min     Drama, Horror, Thriller  ...
# 6442       90 min                 Documentary  ...
# 6443       10 min        Short, Action, Crime  ...
#
#                                         OMDB_Writer  \
# 0          James Cameron, Rick Jaffa, Amanda Silver
# 1     Christopher Markus, Stephen McFeely, Stan Lee
# 2         Ted Elliott, Terry Rossio, Stuart Beattie
# 3                 Joss Whedon, Stan Lee, Jack Kirby
# 4                 Dan Mazeau, Justin Lin, Zach Dean
# ...                                             ...
# 6439                              Christopher Nolan
# 6440                                            N/A
# 6441                               Benjamin Roberds
# 6442                                            N/A
# 6443                          Achyut Prashast Singh
#
#                                          OMDB_Actors  \
# 0     Sam Worthington, Zoe Saldana, Sigourney Weaver
# 1       Robert Downey Jr., Chris Evans, Mark Ruffalo
# 2            Johnny Depp, Penélope Cruz, Ian McShane
# 3       Robert Downey Jr., Chris Evans, Mark Ruffalo
# 4      Vin Diesel, Michelle Rodriguez, Jason Statham
# ...                                              ...
# 6439         Jeremy Theobald, Alex Haw, Lucy Russell
# 6440                                             N/A
# 6441      Eva Boehnke, David Chandler, Maxwell Moody
# 6442   Brian Herzlinger, Drew Barrymore, John August
# 6443                           Achyut Prashast Singh
#
#                          OMDB_Language  \
# 0                              English
# 1     English, Japanese, Xhosa, German
# 2                     English, Spanish
# 3                      English, Korean
# 4                              English
# ...                                ...
# 6439                           English
# 6440                   Arabic, English
# 6441                           English
# 6442                           English
# 6443                             Hindi
#
#                                 OMDB_Country OMDB_Type OMDB_Metascore  \
# 0                              United States     movie             67
# 1                              United States     movie             78
# 2              United States, United Kingdom     movie             45
# 3                              United States     movie             66
# 4                United States, China, Japan     movie             56
# ...                                      ...       ...            ...
# 6439                          United Kingdom     movie             60
# 6440  United States, Germany, United Kingdom     movie             60
# 6441                           United States     movie            N/A
# 6442                           United States     movie             51
# 6443                                   India     movie            N/A
#
#      OMDB_imdbRating OMDB_imdbVotes OMDB_BoxOffice OMDB_Production
# 0                7.6        466,460   $684,075,767             N/A
# 1                8.4      1,223,491   $858,373,000             N/A
# 2                6.6        552,123   $241,071,802             N/A
# 3                7.3        902,827   $459,005,868             N/A
# 4                5.8        101,452   $145,960,660             N/A
# ...              ...            ...            ...             ...
# 6439             7.5         99,294        $48,482             N/A
# 6440             6.9             44         $1,338             N/A
# 6441             5.7             80            N/A             N/A
# 6442             6.5          4,720       $181,041             N/A
# 6443             N/A            N/A            N/A             N/A
#
# [6444 rows x 21 columns]

# %%
# Some movies and shows have the same title. 
# The OMDB search may return non-movies or not have a title match so we remove the rows that are not "movie".
movies_df = movies_df[movies_df['OMDB_Type'] == 'movie']
# Remove the type column from the dataframe
movies_df = movies_df.drop(['OMDB_Type'], axis=1)
print(f'Number of movies in dataset: {len(movies_df)}')
movies_df.head()
# Out:
# Number of movies in dataset: 6051
#     ReleaseDate                                        Movie ProductionBudget  \
# 0   Dec 9, 2022                     Avatar: The Way of Water     $460,000,000
# 1  Apr 23, 2019                            Avengers: Endgame     $400,000,000
# 2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides     $379,000,000
# 3  Apr 22, 2015                      Avengers: Age of Ultron     $365,000,000
# 4  May 17, 2023                                       Fast X     $340,000,000
#
#    DomesticGross   WorldwideGross  \
# 0   $684,075,767   $2,319,591,720
# 1   $858,373,000   $2,788,912,285
# 2   $241,071,802   $1,045,713,802
# 3   $459,005,868   $1,395,316,979
# 4   $145,960,660     $714,414,576
#
#                                     OMDB_Title OMDB_Rated OMDB_Released  \
# 0                     Avatar: The Way of Water      PG-13   16 Dec 2022
# 1                            Avengers: Endgame      PG-13   26 Apr 2019
# 2  Pirates of the Caribbean: On Stranger Tides      PG-13   20 May 2011
# 3                      Avengers: Age of Ultron      PG-13   01 May 2015
# 4                                       Fast X      PG-13   19 May 2023
#
#   OMDB_Runtime                  OMDB_Genre             OMDB_Director  \
# 0      192 min  Action, Adventure, Fantasy             James Cameron
# 1      181 min    Action, Adventure, Drama  Anthony Russo, Joe Russo
# 2      136 min  Action, Adventure, Fantasy              Rob Marshall
# 3      141 min   Action, Adventure, Sci-Fi               Joss Whedon
# 4      141 min    Action, Adventure, Crime           Louis Leterrier
#
#                                      OMDB_Writer  \
# 0       James Cameron, Rick Jaffa, Amanda Silver
# 1  Christopher Markus, Stephen McFeely, Stan Lee
# 2      Ted Elliott, Terry Rossio, Stuart Beattie
# 3              Joss Whedon, Stan Lee, Jack Kirby
# 4              Dan Mazeau, Justin Lin, Zach Dean
#
#                                       OMDB_Actors  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver
# 1    Robert Downey Jr., Chris Evans, Mark Ruffalo
# 2         Johnny Depp, Penélope Cruz, Ian McShane
# 3    Robert Downey Jr., Chris Evans, Mark Ruffalo
# 4   Vin Diesel, Michelle Rodriguez, Jason Statham
#
#                       OMDB_Language                   OMDB_Country  \
# 0                           English                  United States
# 1  English, Japanese, Xhosa, German                  United States
# 2                  English, Spanish  United States, United Kingdom
# 3                   English, Korean                  United States
# 4                           English    United States, China, Japan
#
#   OMDB_Metascore OMDB_imdbRating OMDB_imdbVotes OMDB_BoxOffice OMDB_Production
# 0             67             7.6        466,460   $684,075,767             N/A
# 1             78             8.4      1,223,491   $858,373,000             N/A
# 2             45             6.6        552,123   $241,071,802             N/A
# 3             66             7.3        902,827   $459,005,868             N/A
# 4             56             5.8        101,452   $145,960,660             N/A

# %%
movies_df.to_csv("./Resources/Numbers_OMDB_movies_raw.csv")

# %% [markdown]
# # Format column data types from objects to numbers

# %%
#  # Import and read the data if you screwed up :)
# movies_df = pd.read_csv("./Resources/Numbers_OMDB_movies_raw.csv")
# movies_df = movies_df[['ReleaseDate', 'Movie', 'ProductionBudget', 'DomesticGross', 'WorldwideGross', 
#                         'OMDB_Title', 'OMDB_Rated','OMDB_Released', 'OMDB_Runtime', 'OMDB_Genre', 'OMDB_Director',
#                         'OMDB_Writer', 'OMDB_Actors', 'OMDB_Language', 'OMDB_Country', 'OMDB_Metascore', 
#                         'OMDB_imdbRating', 'OMDB_imdbVotes', 'OMDB_BoxOffice', 'OMDB_Production']]
# movies_df.head()

# %%
# Examine data type of each column
movies_df.dtypes
# Out:
# ReleaseDate         object
# Movie               object
# ProductionBudget    object
# DomesticGross       object
# WorldwideGross      object
# OMDB_Title          object
# OMDB_Rated          object
# OMDB_Released       object
# OMDB_Runtime        object
# OMDB_Genre          object
# OMDB_Director       object
# OMDB_Writer         object
# OMDB_Actors         object
# OMDB_Language       object
# OMDB_Country        object
# OMDB_Metascore      object
# OMDB_imdbRating     object
# OMDB_imdbVotes      object
# OMDB_BoxOffice      object
# OMDB_Production     object
# dtype: object

# %%
# delate all "N/A"
movies_df = movies_df.replace('N/A', '')

# Convert $ objests to floats
movies_df[['ProductionBudget','DomesticGross', 'WorldwideGross', 
           'OMDB_BoxOffice']] = movies_df[['ProductionBudget','DomesticGross',
                                           'WorldwideGross', 'OMDB_BoxOffice']].replace('[\$,\s]', '', regex=True)
movies_df[['ProductionBudget','DomesticGross', 'WorldwideGross', 
           'OMDB_BoxOffice']] = movies_df[['ProductionBudget','DomesticGross', 'WorldwideGross', 
                                           'OMDB_BoxOffice']].apply(pd.to_numeric, errors='coerce')

# # Convert number strings with comma to float
movies_df[['OMDB_imdbVotes']] = movies_df[['OMDB_imdbVotes']].replace('[,\s]', '', regex=True)
movies_df['OMDB_imdbVotes'] = pd.to_numeric(movies_df['OMDB_imdbVotes'], errors='coerce')

# # Convert runtime to float after removing " min"
movies_df[['OMDB_Runtime']] = movies_df[['OMDB_Runtime']].replace('[min\s]', '', regex=True)
movies_df['OMDB_Runtime'] = pd.to_numeric(movies_df['OMDB_Runtime'], errors='coerce')

# Change date to datetime type (Note "ReleaseDate" has inconsistent formatting / typos)
movies_df["OMDB_Released"] = pd.to_datetime(movies_df["OMDB_Released"])

movies_df.dtypes
# Out:
# ReleaseDate                 object
# Movie                       object
# ProductionBudget             int64
# DomesticGross                int64
# WorldwideGross               int64
# OMDB_Title                  object
# OMDB_Rated                  object
# OMDB_Released       datetime64[ns]
# OMDB_Runtime               float64
# OMDB_Genre                  object
# OMDB_Director               object
# OMDB_Writer                 object
# OMDB_Actors                 object
# OMDB_Language               object
# OMDB_Country                object
# OMDB_Metascore              object
# OMDB_imdbRating             object
# OMDB_imdbVotes             float64
# OMDB_BoxOffice             float64
# OMDB_Production             object
# dtype: object

# %%
movies_df.to_csv("./Resources/Numbers_OMDB_formatted.csv")

# %% [markdown]
# # Minor Processing

# %% [markdown]
# ## Convert dates into year and month columns removing date columns

# %%
# #  Import and read the data if you screwed up :)
# movies_df = pd.read_csv("../Resources/Numbers_OMDB_formatted.csv")
# movies_df = movies_df[['ReleaseDate', 'Movie', 'ProductionBudget', 'DomesticGross', 'WorldwideGross', 
#                         'OMDB_Title', 'OMDB_Rated','OMDB_Released', 'OMDB_Runtime', 'OMDB_Genre', 'OMDB_Director',
#                         'OMDB_Writer', 'OMDB_Actors', 'OMDB_Language', 'OMDB_Country', 'OMDB_Metascore', 
#                         'OMDB_imdbRating', 'OMDB_imdbVotes', 'OMDB_BoxOffice', 'OMDB_Production']]
# # Change date to datetime type (Note "ReleaseDate" has inconsistent formatting / typos)
# movies_df["OMDB_Released"] = pd.to_datetime(movies_df["OMDB_Released"])
# movies_df
# Out:
#        ReleaseDate                                        Movie  \
# 0      Dec 9, 2022                     Avatar: The Way of Water
# 1     Apr 23, 2019                            Avengers: Endgame
# 2     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3     Apr 22, 2015                      Avengers: Age of Ultron
# 4     May 17, 2023                                       Fast X
# ...            ...                                          ...
# 6046   Apr 2, 1999                                    Following
# 6047  Jul 13, 2005                Return to the Land of Wonders
# 6048  Sep 29, 2015                         A Plague So Pleasant
# 6049   Aug 5, 2005                            My Date With Drew
# 6050   Mar 2, 2021                                       Neeras
#
#       ProductionBudget  DomesticGross  WorldwideGross  \
# 0            460000000      684075767      2319591720
# 1            400000000      858373000      2788912285
# 2            379000000      241071802      1045713802
# 3            365000000      459005868      1395316979
# 4            340000000      145960660       714414576
# ...                ...            ...             ...
# 6046              6000          48482          240495
# 6047              5000           1338            1338
# 6048              1400              0               0
# 6049              1100         181041          181041
# 6050                86              0               0
#
#                                        OMDB_Title OMDB_Rated OMDB_Released  \
# 0                        Avatar: The Way of Water      PG-13    2022-12-16
# 1                               Avengers: Endgame      PG-13    2019-04-26
# 2     Pirates of the Caribbean: On Stranger Tides      PG-13    2011-05-20
# 3                         Avengers: Age of Ultron      PG-13    2015-05-01
# 4                                          Fast X      PG-13    2023-05-19
# ...                                           ...        ...           ...
# 6046                                    Following          R    1999-11-05
# 6047                Return to the Land of Wonders        NaN    2004-04-27
# 6048                         A Plague So Pleasant        NaN    2013-01-26
# 6049                            My Date with Drew         PG    2005-09-30
# 6050                                       Neeras  Not Rated    2021-03-02
#
#       OMDB_Runtime                  OMDB_Genre  \
# 0            192.0  Action, Adventure, Fantasy
# 1            181.0    Action, Adventure, Drama
# 2            136.0  Action, Adventure, Fantasy
# 3            141.0   Action, Adventure, Sci-Fi
# 4            141.0    Action, Adventure, Crime
# ...            ...                         ...
# 6046          69.0    Crime, Mystery, Thriller
# 6047          88.0            Documentary, War
# 6048          76.0     Drama, Horror, Thriller
# 6049          90.0                 Documentary
# 6050          10.0        Short, Action, Crime
#
#                                OMDB_Director  \
# 0                              James Cameron
# 1                   Anthony Russo, Joe Russo
# 2                               Rob Marshall
# 3                                Joss Whedon
# 4                            Louis Leterrier
# ...                                      ...
# 6046                       Christopher Nolan
# 6047                        Maysoon Pachachi
# 6048          Benjamin Roberds, Jordan Reyes
# 6049  Jon Gunn, Brian Herzlinger, Brett Winn
# 6050                   Achyut Prashast Singh
#
#                                         OMDB_Writer  \
# 0          James Cameron, Rick Jaffa, Amanda Silver
# 1     Christopher Markus, Stephen McFeely, Stan Lee
# 2         Ted Elliott, Terry Rossio, Stuart Beattie
# 3                 Joss Whedon, Stan Lee, Jack Kirby
# 4                 Dan Mazeau, Justin Lin, Zach Dean
# ...                                             ...
# 6046                              Christopher Nolan
# 6047                                            NaN
# 6048                               Benjamin Roberds
# 6049                                            NaN
# 6050                          Achyut Prashast Singh
#
#                                          OMDB_Actors  \
# 0     Sam Worthington, Zoe Saldana, Sigourney Weaver
# 1       Robert Downey Jr., Chris Evans, Mark Ruffalo
# 2            Johnny Depp, Penélope Cruz, Ian McShane
# 3       Robert Downey Jr., Chris Evans, Mark Ruffalo
# 4      Vin Diesel, Michelle Rodriguez, Jason Statham
# ...                                              ...
# 6046         Jeremy Theobald, Alex Haw, Lucy Russell
# 6047                                             NaN
# 6048      Eva Boehnke, David Chandler, Maxwell Moody
# 6049   Brian Herzlinger, Drew Barrymore, John August
# 6050                           Achyut Prashast Singh
#
#                          OMDB_Language  \
# 0                              English
# 1     English, Japanese, Xhosa, German
# 2                     English, Spanish
# 3                      English, Korean
# 4                              English
# ...                                ...
# 6046                           English
# 6047                   Arabic, English
# 6048                           English
# 6049                           English
# 6050                             Hindi
#
#                                 OMDB_Country  OMDB_Metascore  OMDB_imdbRating  \
# 0                              United States            67.0              7.6
# 1                              United States            78.0              8.4
# 2              United States, United Kingdom            45.0              6.6
# 3                              United States            66.0              7.3
# 4                United States, China, Japan            56.0              5.8
# ...                                      ...             ...              ...
# 6046                          United Kingdom            60.0              7.5
# 6047  United States, Germany, United Kingdom            60.0              6.9
# 6048                           United States             NaN              5.7
# 6049                           United States            51.0              6.5
# 6050                                   India             NaN              NaN
#
#       OMDB_imdbVotes  OMDB_BoxOffice OMDB_Production
# 0           466460.0     684075767.0             NaN
# 1          1223491.0     858373000.0             NaN
# 2           552123.0     241071802.0             NaN
# 3           902827.0     459005868.0             NaN
# 4           101452.0     145960660.0             NaN
# ...              ...             ...             ...
# 6046         99294.0         48482.0             NaN
# 6047            44.0          1338.0             NaN
# 6048            80.0             NaN             NaN
# 6049          4720.0        181041.0             NaN
# 6050             NaN             NaN             NaN
#
# [6051 rows x 20 columns]

# %%
movies_df.dtypes
# Out:
# ReleaseDate                 object
# Movie                       object
# ProductionBudget             int64
# DomesticGross                int64
# WorldwideGross               int64
# OMDB_Title                  object
# OMDB_Rated                  object
# OMDB_Released       datetime64[ns]
# OMDB_Runtime               float64
# OMDB_Genre                  object
# OMDB_Director               object
# OMDB_Writer                 object
# OMDB_Actors                 object
# OMDB_Language               object
# OMDB_Country                object
# OMDB_Metascore             float64
# OMDB_imdbRating            float64
# OMDB_imdbVotes             float64
# OMDB_BoxOffice             float64
# OMDB_Production             object
# dtype: object

# %%
movies_df["ReleaseYear"] = pd.DatetimeIndex(movies_df['OMDB_Released']).year
movies_df["ReleaseMonth"] = pd.DatetimeIndex(movies_df['OMDB_Released']).month
movies_df = movies_df.drop(['ReleaseDate', 'OMDB_Released'], axis=1)
movies_df.head()
# Out:
#                                          Movie  ProductionBudget  \
# 0                     Avatar: The Way of Water         460000000
# 1                            Avengers: Endgame         400000000
# 2  Pirates of the Caribbean: On Stranger Tides         379000000
# 3                      Avengers: Age of Ultron         365000000
# 4                                       Fast X         340000000
#
#    DomesticGross  WorldwideGross                                   OMDB_Title  \
# 0      684075767      2319591720                     Avatar: The Way of Water
# 1      858373000      2788912285                            Avengers: Endgame
# 2      241071802      1045713802  Pirates of the Caribbean: On Stranger Tides
# 3      459005868      1395316979                      Avengers: Age of Ultron
# 4      145960660       714414576                                       Fast X
#
#   OMDB_Rated  OMDB_Runtime                  OMDB_Genre  \
# 0      PG-13         192.0  Action, Adventure, Fantasy
# 1      PG-13         181.0    Action, Adventure, Drama
# 2      PG-13         136.0  Action, Adventure, Fantasy
# 3      PG-13         141.0   Action, Adventure, Sci-Fi
# 4      PG-13         141.0    Action, Adventure, Crime
#
#               OMDB_Director                                    OMDB_Writer  \
# 0             James Cameron       James Cameron, Rick Jaffa, Amanda Silver
# 1  Anthony Russo, Joe Russo  Christopher Markus, Stephen McFeely, Stan Lee
# 2              Rob Marshall      Ted Elliott, Terry Rossio, Stuart Beattie
# 3               Joss Whedon              Joss Whedon, Stan Lee, Jack Kirby
# 4           Louis Leterrier              Dan Mazeau, Justin Lin, Zach Dean
#
#                                       OMDB_Actors  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver
# 1    Robert Downey Jr., Chris Evans, Mark Ruffalo
# 2         Johnny Depp, Penélope Cruz, Ian McShane
# 3    Robert Downey Jr., Chris Evans, Mark Ruffalo
# 4   Vin Diesel, Michelle Rodriguez, Jason Statham
#
#                       OMDB_Language                   OMDB_Country  \
# 0                           English                  United States
# 1  English, Japanese, Xhosa, German                  United States
# 2                  English, Spanish  United States, United Kingdom
# 3                   English, Korean                  United States
# 4                           English    United States, China, Japan
#
#    OMDB_Metascore  OMDB_imdbRating  OMDB_imdbVotes  OMDB_BoxOffice  \
# 0            67.0              7.6        466460.0     684075767.0
# 1            78.0              8.4       1223491.0     858373000.0
# 2            45.0              6.6        552123.0     241071802.0
# 3            66.0              7.3        902827.0     459005868.0
# 4            56.0              5.8        101452.0     145960660.0
#
#   OMDB_Production  ReleaseYear  ReleaseMonth
# 0             NaN       2022.0          12.0
# 1             NaN       2019.0           4.0
# 2             NaN       2011.0           5.0
# 3             NaN       2015.0           5.0
# 4             NaN       2023.0           5.0

# %%
movies_df.columns
# Out:
# Index(['Movie', 'ProductionBudget', 'DomesticGross', 'WorldwideGross',
#        'OMDB_Title', 'OMDB_Rated', 'OMDB_Runtime', 'OMDB_Genre',
#        'OMDB_Director', 'OMDB_Writer', 'OMDB_Actors', 'OMDB_Language',
#        'OMDB_Country', 'OMDB_Metascore', 'OMDB_imdbRating', 'OMDB_imdbVotes',
#        'OMDB_BoxOffice', 'OMDB_Production', 'ReleaseYear', 'ReleaseMonth'],
#       dtype='object')

# %% [markdown]
# # Investigate Inputs / Features: should any be consolidated or truncated
#
# Inputs / Features = ['Movie', 'ProductionBudget',  'OMDB_Title', 'OMDB_Rated', 'OMDB_Runtime', 'OMDB_Genre', 'OMDB_Director', 'OMDB_Writer', 'OMDB_Actors', 'OMDB_Language', 'OMDB_Country',  'OMDB_Production', 'ReleaseYear', 'ReleaseMonth']

# %%
# Look at Rated values to see if consolidation would be beneficial
movies_df['OMDB_Rated'].value_counts()
# Out:
# R            2516
# PG-13        1796
# PG            841
# Not Rated     325
# G             144
# Approved       44
# Unrated        39
# Passed         36
# TV-MA          34
# TV-PG          12
# TV-14           9
# NC-17           9
# TV-G            5
# X               4
# GP              3
# M/PG            3
# 18+             2
# M               2
# 16+             1
# 13+             1
# Name: OMDB_Rated, dtype: int64

# %%
# Define Consolidate Rated Lists:
# reference https://en.wikipedia.org/wiki/Motion_Picture_Association_film_rating_system
kids = ['PG', 'G', 'TV-PG', 'TV-G', 'GP', 'M/PG', 'M']
teens = ['PG-13', 'TV-14', '16+', '13+']
adults = ['R', 'TV-MA', 'NC-17', 'X', '18+']
Unknown = ['Not Rated', 'Approved', 'Unrated', 'Passed']

for index, row in movies_df.iterrows():
    movie_rating = row['OMDB_Rated']
    if movie_rating in kids:
        movies_df.at[index,'OMDB_Rated'] = 'kids'
    elif movie_rating in teens:
        movies_df.at[index,'OMDB_Rated'] = 'teens'
    elif movie_rating in adults:
        movies_df.at[index,'OMDB_Rated'] = 'adults'
    else:
        movies_df.at[index,'OMDB_Rated'] = 'unknown'

# df["grade"] = df.apply(lambda x: 'A+' if ((x['score']>40)&(x['score']<50)) else x["grade"], axis=1)
# movies_df.OMDB_Rated = np.where((movies_df.OMDB_Rated in kids), 'kids', movies_df.OMDB_Rated)

movies_df['OMDB_Rated'].value_counts()
# Out:
# adults     2565
# teens      1807
# kids       1010
# unknown     669
# Name: OMDB_Rated, dtype: int64

# %%
# Look at Release Month values to see distribution
movies_df['ReleaseMonth'].value_counts()
# Out:
# 10.0    578
# 11.0    540
# 8.0     540
# 3.0     520
# 12.0    503
# 6.0     501
# 7.0     487
# 4.0     486
# 9.0     485
# 1.0     481
# 2.0     460
# 5.0     415
# Name: ReleaseMonth, dtype: int64

# %%
# Look at Release Year values to see if consolidation / removal would be beneficial
year_hist = movies_df['ReleaseYear'].hist(bins=11, legend=True)

# %%
# Drop the earlier movies (low count and significant $ differences)
movies_df = movies_df[movies_df['ReleaseYear'] >= 1980]

print(f'Number of movies in dataset: {len(movies_df)}')
year_hist2 = movies_df['ReleaseYear'].hist(bins=11, legend=True)
# Out:
# Number of movies in dataset: 5673

# %%
# Look at budget values to see if consolidation would be beneficial
budget_hist = movies_df['ProductionBudget'].hist(bins=11, legend=True)

# %%
lower_budget_movies_df = movies_df[movies_df['ProductionBudget'] <= 100000000]
print(f'Number of movies in dataset: {len(lower_budget_movies_df)}')
lower_budget_hist = lower_budget_movies_df['ProductionBudget'].hist(bins=11, legend=True)
# Out:
# Number of movies in dataset: 5258

# %%
# Look at Runtime values to see if consolidation / removal would be beneficial
year_hist = movies_df['OMDB_Runtime'].hist(bins=11, legend=True)

# %%
mid_runtime_movies_df = movies_df[(movies_df['OMDB_Runtime'] >= 60) & (movies_df['OMDB_Runtime'] <= 180)]
print(f'Number of movies in dataset: {len(mid_runtime_movies_df)}')
mid_runtime_hist = mid_runtime_movies_df['OMDB_Runtime'].hist(bins=11, legend=True)
# Out:
# Number of movies in dataset: 5554

# %%
# Look at Production values to see what we have
movies_df['OMDB_Production'].value_counts()
# Out:
# Paramount Pictures                                             2
# 20th Century Fox                                               2
# De Line Pictures                                               1
# Metro-Goldwyn-Mayer, United Artists                            1
# Engine 15 Media Corp                                           1
# Live Home Video                                                1
# Weston Pictures                                                1
# High Five Films                                                1
# Phase 4 Films                                                  1
# France 2 Cinéma, Mars Film                                     1
# Zebra                                                          1
# Blumhouse, Mosaic                                              1
# Universal Pictures, QC Entertainment, Blumhouse Productions    1
# Caviar                                                         1
# Green/Renzi                                                    1
# 2.4.7. Films                                                   1
# Lyrick                                                         1
# New Glory Productions                                          1
# Miramax                                                        1
# Amazon Studios/Bleecker Street Media                           1
# The Orchard                                                    1
# Bandai                                                         1
# Rocket Pictures                                                1
# Maverick Entertainment                                         1
# Carousel, DiNovi Pictures                                      1
# Dan Lund Films                                                 1
# Columbia Pictures                                              1
# Disney                                                         1
# Faith vs. Fate Productions                                     1
# Name: OMDB_Production, dtype: int64

# %% [markdown]
# ## Notes on feature distributions:
# * OMDB_Rated had 20 categories with overlap which have been reduced to 4 categories: kids (G, PG), teens (PG13), adults(NC-17+, R), and unknown
# * Release Month is relatively evenly distributed across months
# * Release Year indicates a tail of movies pre-1980 which have been truncated (it could be beneficial to modify that cut-off to 1995).
# * Budgets have a tail above 100,000,000 with the biggest chunk at <= 20,000,000 (another potential break could be 50,000,000). All have been kept for the minor processing.
# * Runtime has most movies between 80 and 150 minutes with tails on both ends. All have been kept for minor processing.
# * OMDB_Production has very few values filled
# * OMDB_Genre, OMDB_Director, OMDB_Writer, OMDB_Actors, OMDB_Language, OMDB_Country all have lists within the list

# %% [markdown]
# # Investigate Outcomes Distributions
#
# Outputs  / Targets = [ 'DomesticGross', 'WorldwideGross',  'OMDB_Metascore', 'OMDB_imdbRating', 'OMDB_imdbVotes', 'OMDB_BoxOffice']

# %%
meta_hist = movies_df['OMDB_Metascore'].hist(bins=11, legend=True)

# %%
imdb_rating_hist = movies_df['OMDB_imdbRating'].hist(bins=11, legend=True)

# %%
box_office_hist = movies_df['OMDB_BoxOffice'].hist(bins=33, legend=True)

# %%
lower_boxoffice_movies_df = movies_df[movies_df['OMDB_BoxOffice'] <= 200000000]
print(f'Number of movies in dataset: {len(lower_boxoffice_movies_df)}')
lower_box_office_hist = lower_boxoffice_movies_df['OMDB_BoxOffice'].hist(bins=11, legend=True)
# Out:
# Number of movies in dataset: 4783

# %% [markdown]
# ## Notes on ouput distributions
# * OMDB_Metascore has a relatively normal distribution
# * OMDB_imbdRating has a relatively normal distribution with a tail on the lower end
# * OMDB_BoxOffice has a long tail above 200,000,000; most fall under 100,000,000

# %% [markdown]
# # Review potential correlations
#
# Inputs / Features = ['Movie', 'ProductionBudget',  'OMDB_Title', 'OMDB_Rated', 'OMDB_Runtime', 'OMDB_Genre', 'OMDB_Director', 'OMDB_Writer', 'OMDB_Actors', 'OMDB_Language', 'OMDB_Country',  'OMDB_Production', 'ReleaseYear', 'ReleaseMonth']
#
# Outputs  / Targets = [ 'DomesticGross', 'WorldwideGross',  'OMDB_Metascore', 'OMDB_imdbRating', 'OMDB_imdbVotes', 'OMDB_BoxOffice']

# %%
# Create a function to create the plot for linear regression
def create_regression_plot(df, x_col, y_col):
    # Define the x and y
    df_no_nan = df[[x_col, y_col]]
    df_no_nan =df_no_nan.dropna()

    x_values = df_no_nan[x_col]
    y_values = df_no_nan[y_col]

    # Calculate the regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot the different factors in a scatter plot
    fig = plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel(x_col)
    plt.ylabel(y_col)

    # Plot the linear equation
    eq_x_coord = 0.5 * (max(x_values) + min(x_values))
    eq_y_coord = 0.1 * (max(y_values) - min(y_values)) + min(y_values)
    plt.annotate(line_eq,(eq_x_coord,eq_y_coord),fontsize=15,color="red")
    
    return(rvalue, fig)

# %% [markdown]
# ## Review outcome to outcome relationships

# %% [markdown]
# ### Verify assumed Metascore - IMDB Rating relationship

# %%
rvalue, fig =  create_regression_plot(movies_df, 'OMDB_Metascore', 'OMDB_imdbRating')

print(f"The r-squared is: {rvalue**2}")
plt.show(fig)
# Out:
# The r-squared is: 0.5445182157784217

# %% [markdown]
# ### Check OMDB_BoxOffice vs. IMDB rating / Metascore

# %%
rvalue, fig =  create_regression_plot(movies_df, 'OMDB_BoxOffice', 'OMDB_Metascore')

print(f"The r-squared is: {rvalue**2}")
plt.show(fig)
# Out:
# The r-squared is: 0.0280842946493175

# %%
rvalue, fig =  create_regression_plot(movies_df, 'OMDB_BoxOffice', 'OMDB_imdbRating')

print(f"The r-squared is: {rvalue**2}")
plt.show(fig)
# Out:
# The r-squared is: 0.058252755566425424

# %% [markdown]
# ## Review input to outcome relationships

# %% [markdown]
# ### Check for relationship of production budget vs. IMDB rating / MetaScore / BoxOffice

# %%
rvalue, fig =  create_regression_plot(movies_df, 'ProductionBudget', 'OMDB_imdbRating')

print(f"The r-squared is: {rvalue**2}")
plt.show(fig)
# Out:
# The r-squared is: 0.013559131352799637

# %%
rvalue, fig =  create_regression_plot(movies_df, 'ProductionBudget', 'OMDB_Metascore')

print(f"The r-squared is: {rvalue**2}")
plt.show(fig)
# Out:
# The r-squared is: 0.0001625780248619153

# %%
rvalue, fig =  create_regression_plot(movies_df, 'ProductionBudget', 'OMDB_BoxOffice')

print(f"The r-squared is: {rvalue**2}")
plt.show(fig)
# Out:
# The r-squared is: 0.4432647435601033

# %% [markdown]
# ### What about runtime vs. rating?

# %%
rvalue, fig =  create_regression_plot(movies_df, 'OMDB_Runtime', 'OMDB_imdbRating')

print(f"The r-squared is: {rvalue**2}")
plt.show(fig)
# Out:
# The r-squared is: 0.11580544325115477

# %% [markdown]
# ### What about trends with release month

# %%
# Create a box plot for each month's BoxOffice
movies_df_no_nan = movies_df[['ReleaseMonth', 'OMDB_BoxOffice']]
movies_df_no_nan = movies_df_no_nan.dropna()

movies_df_no_nan = movies_df_no_nan.pivot_table(index=movies_df_no_nan.index, columns='ReleaseMonth', values='OMDB_BoxOffice')

boxplot = movies_df_no_nan.boxplot()

# %%
# Create a box plot for each month's BoxOffice for movies with Box Office <=20,0000,000
movies_df_no_nan = movies_df[['ReleaseMonth', 'OMDB_BoxOffice']]
movies_df_no_nan = movies_df_no_nan.dropna()

lower_movies_df_no_nan = movies_df_no_nan[movies_df['OMDB_BoxOffice'] <= 200000000]

lower_movies_df_no_nan = lower_movies_df_no_nan.pivot_table(index=lower_movies_df_no_nan.index, 
                                                            columns='ReleaseMonth', values='OMDB_BoxOffice')

boxplot = lower_movies_df_no_nan.boxplot()
# Out:
# C:\Users\vt_be\AppData\Local\Temp\ipykernel_29768\1342650851.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   lower_movies_df_no_nan = movies_df_no_nan[movies_df['OMDB_BoxOffice'] <= 200000000]

# %%
# Create a box plot for each month's BoxOffice
movies_df_no_nan = movies_df[['ReleaseMonth', 'OMDB_imdbRating']]
movies_df_no_nan = movies_df_no_nan.dropna()

movies_df_no_nan = movies_df_no_nan.pivot_table(index=movies_df_no_nan.index, columns='ReleaseMonth', values='OMDB_imdbRating')

boxplot = movies_df_no_nan.boxplot()

# %% [markdown]
# ## Notes on Ouput Relationships
# * Metascore and imdbRating have a mediocre positive relationship
# * Box Office does **not** have a meaningful relationship with Metascore nore imdbRating
# ## Notes on Input to Output Relationships
# * Budget does **not** have a meaningful relationship to imdbRating nor Metascore
# * Budget does have a minor positve relationship with Box Office
# * Runtime does **not** have a meaningful relationship to imdbRating
# * Box Office box-and-whisker plots by month show quite a few outliers with Box Office above 20,000,000. Removing all movies with Box Office greater than 20,000,000 does show June, July, and December with the best Box Office return
# * imdbRating box-and-whisker plots by month do not show much variation across months

# %% [markdown]
# # Export final dataframe

# %%
movies_df.to_csv("./Resources/Numbers_OMDB_processed.csv")

# %% [markdown]
# # Summary Findings to Kick-Off Machine Learning Experiments
#
# * Single numeric feature relationships to the IMDB Rating outcome are very weak indicating challenges to using numeric only features to predict viewer ratings.
# * Using a critic rating (e.g., Metascore) available to a release can help improve predicting viewer ratings (e.g., IMDB Rating).
# * Budget has a minor positive relationship with Box Office but not with IMDB Rating so it could be helpful in predicting Box Office.
# * Release month seems to have little impact on IMDB Rating but could be a useful factor in predicting Box Office.
