# %%
import pandas as pd

# Define the file path
file_path = "Resources/movies_formatted.csv"

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df['OMDB_Director'].head(30)
# Out:
# 0                  James Cameron
# 1       Anthony Russo, Joe Russo
# 2                   Rob Marshall
# 3                    Joss Whedon
# 4                Louis Leterrier
# 5       Anthony Russo, Joe Russo
# 6                 Gore Verbinski
# 7                    Zack Snyder
# 8                  James Mangold
# 9          Christopher McQuarrie
# 10              Nikolai Kurbatov
# 11                    Ron Howard
# 12                   Nia DaCosta
# 13                Andrew Stanton
# 14                   Zack Snyder
# 15     Roger Allers, Rob Minkoff
# 16    Nathan Greno, Byron Howard
# 17                     Sam Raimi
# 18                  Ryan Coogler
# 19      Anthony Russo, Joe Russo
# 20                    James Gunn
# 21                 Taika Waititi
# 22                   David Yates
# 23     Ron Clements, John Musker
# 24                 Peter Jackson
# 25                 Peter Jackson
# 26                  F. Gary Gray
# 27            Cary Joji Fukunaga
# 28                    Sam Mendes
# 29                 James Cameron
# Name: OMDB_Director, dtype: object

# %%
# Initialize an empty dictionary to store director instances
director_dict = {}

# %%
# Initialize a variable to keep track of the running sum of box office and production budget for each director
running_sum = {'box_office': {}, 'production_budget': {}}

# %%
# Iterate through the DataFrame rows
for index, row in df.iterrows():
    # Get director names from the 'OMDB_Director' column
    directors = row['OMDB_Director']
    
    # Check if the value is not NaN and is a string
    if pd.notna(directors) and isinstance(directors, str):
        # Split director names separated by commas
        director_list = [director.strip() for director in directors.split(',')]
        
        # Get the corresponding box office and production budget values
        box_office = row['OMDB_BoxOffice']
        production_budget = row['ProductionBudget']
        
        # Iterate through director names and update the director_dict
        for director in director_list:
            if director in director_dict:
                # Increment the instance count if the director is already in the dictionary
                director_dict[director]['instances'] += 1
                
                # Add the box office and production budget values to the running sum for the director
                running_sum['box_office'][director] = running_sum['box_office'].get(director, 0) + box_office
                running_sum['production_budget'][director] = running_sum['production_budget'].get(director, 0) + production_budget
                
                # Update the total box office and production budget values in the director_dict
                director_dict[director]['total_box_office'] = running_sum['box_office'][director]
                director_dict[director]['total_production_budget'] = running_sum['production_budget'][director]
            else:
                # Add the director to the dictionary with an initial instance count of 1
                director_dict[director] = {
                    'instances': 1,
                    'total_box_office': box_office,
                    'total_production_budget': production_budget
                }
                
                # Initialize the running sum for the director
                running_sum['box_office'][director] = box_office
                running_sum['production_budget'][director] = production_budget

# %%
# Display the populated director dictionary
print(director_dict)
# Out:
# {'James Cameron': {'instances': 8, 'total_box_office': 2673746084.0}, 'Anthony Russo': {'instances': 8, 'total_box_office': nan}, 'Joe Russo': {'instances': 8, 'total_box_office': nan}, 'Rob Marshall': {'instances': 6, 'total_box_office': 788887603.0}, 'Joss Whedon': {'instances': 5, 'total_box_office': 1756750722.0}, 'Louis Leterrier': {'instances': 7, 'total_box_office': 757092622.0}, 'Gore Verbinski': {'instances': 7, 'total_box_office': 1153971900.0}, 'Zack Snyder': {'instances': 10, 'total_box_office': nan}, 'James Mangold': {'instances': 9, 'total_box_office': 908798110.0}, 'Christopher McQuarrie': {'instances': 5, 'total_box_office': 673463261.0}, 'Nikolai Kurbatov': {'instances': 1, 'total_box_office': nan}, 'Ron Howard': {'instances': 18, 'total_box_office': nan}, 'Nia DaCosta': {'instances': 1, 'total_box_office': nan}, 'Andrew Stanton': {'instances': 5, 'total_box_office': 1326823651.0}, 'Roger Allers': {'instances': 4, 'total_box_office': 931398302.0}, 'Rob Minkoff': {'instances': 8, 'total_box_office': 1307800075.0}, 'Nathan Greno': {'instances': 1, 'total_box_office': 200821936.0}, 'Byron Howard': {'instances': 4, 'total_box_office': 752237385.0}, 'Sam Raimi': {'instances': 12, 'total_box_office': 1895450515.0}, 'Ryan Coogler': {'instances': 4, 'total_box_office': 1280135848.0}, 'James Gunn': {'instances': 6, 'total_box_office': 1146475107.0}, 'Taika Waititi': {'instances': 4, 'total_box_office': 696891493.0}, 'David Yates': {'instances': 6, 'total_box_office': 1210804482.0}, 'Ron Clements': {'instances': 8, 'total_box_office': 1135802845.0}, 'John Musker': {'instances': 8, 'total_box_office': 1135802845.0}, 'Peter Jackson': {'instances': 12, 'total_box_office': 2556697534.0}, 'F. Gary Gray': {'instances': 10, 'total_box_office': 837953766.0}, 'Cary Joji Fukunaga': {'instances': 2, 'total_box_office': 160981784.0}, 'Sam Mendes': {'instances': 8, 'total_box_office': 993235539.0}, 'Bryan Singer': {'instances': 8, 'total_box_office': 1135019979.0}, 'Christopher Nolan': {'instances': 12, 'total_box_office': 2389172169.0}, 'Joachim Rønning': {'instances': 3, 'total_box_office': nan}, 'Espen Sandberg': {'instances': 2, 'total_box_office': nan}, 'Marc Forster': {'instances': 10, 'total_box_office': 674616055.0}, 'Andrew Adamson': {'instances': 4, 'total_box_office': 863523610.0}, 'Marc Webb': {'instances': 3, 'total_box_office': 489685808.0}, 'Peter Berg': {'instances': 9, 'total_box_office': 653054678.0}, 'Michael Bay': {'instances': 14, 'total_box_office': nan}, 'Colin Trevorrow': {'instances': 4, 'total_box_office': 1038773636.0}, 'Barry Sonnenfeld': {'instances': 9, 'total_box_office': 918508930.0}, 'Brett Ratner': {'instances': 9, 'total_box_office': 1058083205.0}, 'Ridley Scott': {'instances': 22, 'total_box_office': 1716819615.0}, 'Chris Weitz': {'instances': 7, 'total_box_office': 595428116.0}, 'James Wan': {'instances': 10, 'total_box_office': nan}, 'Jon Watts': {'instances': 4, 'total_box_office': 1538982847.0}, 'Brad Bird': {'instances': 7, 'total_box_office': 1612015653.0}, 'Gareth Edwards': {'instances': 5, 'total_box_office': 974729671.0}, 'Angus MacLane': {'instances': 2, 'total_box_office': 604602749.0}, 'Josh Cooley': {'instances': 1, 'total_box_office': 434038008.0}, 'Lee Unkrich': {'instances': 5, 'total_box_office': 1542802591.0}, 'Shane Black': {'instances': 5, 'total_box_office': 909558215.0}, 'Matt Reeves': {'instances': 6, 'total_box_office': 822611090.0}, 'Tim Burton': {'instances': 19, 'total_box_office': 2302967434.0}, 'Dan Scanlon': {'instances': 2, 'total_box_office': 330047909.0}, 'Peyton Reed': {'instances': 6, 'total_box_office': 896129063.0}, 'John Lasseter': {'instances': 5, 'total_box_office': 1067411801.0}, 'Bradford Lewis': {'instances': 1, 'total_box_office': 191452396.0}, 'Cate Shortland': {'instances': 2, 'total_box_office': 183680315.0}, 'David Leitch': {'instances': 5, 'total_box_office': 696642977.0}, 'Justin Lin': {'instances': 7, 'total_box_office': 763125898.0}, 'Joseph Kosi ...
