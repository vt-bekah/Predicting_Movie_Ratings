# %%
import pandas as pd

# %%
# Read the CSV file into a DataFrame
movies_raw_imdb_df = pd.read_csv('Resources/movies_raw_imdb.csv')
larger_movies_raw_df = pd.read_csv('Resources/larger_movies_raw.csv')

# %%
movies_raw_imdb_df.head()
# Out:
#    Unnamed: 0     tconst  averageRating  numVotes titleType  isAdult  \
# 0           0  tt0013274            6.8        59     movie        0
# 1           1  tt0015414            5.2        16     movie        0
# 2           2  tt0015724            6.1        27     movie        0
# 3           3  tt0035423            6.4     87965     movie        0
# 4           4  tt0036606            6.5       345     movie        0
#
#    startYear  endYear  runtimeMinutes                  genres  \
# 0       2021        0              94             Documentary
# 1       2000        0              60                       0
# 2       1993        0             102   Drama,Mystery,Romance
# 3       2001        0             118  Comedy,Fantasy,Romance
# 4       1983        0             118               Drama,War
#
#                          Movie
# 0  Istoriya grazhdanskoy voyny
# 1       La tierra de los toros
# 2                Dama de noche
# 3               Kate & Leopold
# 4  Another Time, Another Place

# %%
larger_movies_raw_df.head()
# Out:
#    Unnamed: 0     tconst                   OMDB_Title OMDB_Rated  \
# 0           0  tt0013274  Istoriya grazhdanskoy voyny        NaN
# 1           1  tt0015414       La tierra de los toros        NaN
# 2           2  tt0015724                Dama de noche        NaN
# 3           3  tt0035423               Kate & Leopold      PG-13
# 4           4  tt0036606  Another Time, Another Place          R
#
#   OMDB_Released OMDB_Runtime                OMDB_Genre  \
# 0   10 May 2022       94 min               Documentary
# 1           NaN       60 min                       NaN
# 2   18 Mar 1993      102 min   Drama, Mystery, Romance
# 3   25 Dec 2001      118 min  Comedy, Fantasy, Romance
# 4   11 May 1984      118 min                Drama, War
#
#                    OMDB_Director  \
# 0  Nikolai Izvolov, Dziga Vertov
# 1                       Musidora
# 2              Eva López Sánchez
# 3                  James Mangold
# 4                Michael Radford
#
#                                          OMDB_Writer  \
# 0                                                NaN
# 1                                                NaN
# 2          Eva López Sánchez, David Martin del Campo
# 3                       Steven Rogers, James Mangold
# 4  Jessie Kesson, John Francis Lane, Michael Radford
#
#                                          OMDB_Actors     OMDB_Language  \
# 0                                                NaN              None
# 1                           Antonio Cañero, Musidora              None
# 2  Rafael Sánchez Navarro, Cecilia Toussaint, Mig...           Spanish
# 3             Meg Ryan, Hugh Jackman, Liev Schreiber   English, French
# 4  Phyllis Logan, Giovanni Mauriello, Gianluca Fa...  English, Italian
#
#      OMDB_Country OMDB_Type  OMDB_Metascore  OMDB_imdbRating OMDB_imdbVotes  \
# 0    Soviet Union     movie             NaN              NaN             58
# 1   Spain, France     movie             NaN              6.6             16
# 2          Mexico     movie             NaN              5.8             27
# 3   United States     movie            44.0              6.4         87,977
# 4  United Kingdom     movie             NaN              6.5            338
#
#   OMDB_BoxOffice OMDB_Production
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3    $47,121,859             NaN
# 4            NaN             NaN

# %%
# Merge the DataFrames on the 'tconst' column
merged_df = pd.merge(movies_raw_imdb_df, larger_movies_raw_df, on='tconst')

# %%
merged_df.head()
# Out:
#    Unnamed: 0_x     tconst  averageRating  numVotes titleType  isAdult  \
# 0             0  tt0013274            6.8        59     movie        0
# 1             1  tt0015414            5.2        16     movie        0
# 2             2  tt0015724            6.1        27     movie        0
# 3             3  tt0035423            6.4     87965     movie        0
# 4             4  tt0036606            6.5       345     movie        0
#
#    startYear  endYear  runtimeMinutes                  genres  ...  \
# 0       2021        0              94             Documentary  ...
# 1       2000        0              60                       0  ...
# 2       1993        0             102   Drama,Mystery,Romance  ...
# 3       2001        0             118  Comedy,Fantasy,Romance  ...
# 4       1983        0             118               Drama,War  ...
#
#                                          OMDB_Writer  \
# 0                                                NaN
# 1                                                NaN
# 2          Eva López Sánchez, David Martin del Campo
# 3                       Steven Rogers, James Mangold
# 4  Jessie Kesson, John Francis Lane, Michael Radford
#
#                                          OMDB_Actors     OMDB_Language  \
# 0                                                NaN              None
# 1                           Antonio Cañero, Musidora              None
# 2  Rafael Sánchez Navarro, Cecilia Toussaint, Mig...           Spanish
# 3             Meg Ryan, Hugh Jackman, Liev Schreiber   English, French
# 4  Phyllis Logan, Giovanni Mauriello, Gianluca Fa...  English, Italian
#
#      OMDB_Country OMDB_Type OMDB_Metascore OMDB_imdbRating OMDB_imdbVotes  \
# 0    Soviet Union     movie            NaN             NaN             58
# 1   Spain, France     movie            NaN             6.6             16
# 2          Mexico     movie            NaN             5.8             27
# 3   United States     movie           44.0             6.4         87,977
# 4  United Kingdom     movie            NaN             6.5            338
#
#   OMDB_BoxOffice OMDB_Production
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3    $47,121,859             NaN
# 4            NaN             NaN
#
# [5 rows x 28 columns]
